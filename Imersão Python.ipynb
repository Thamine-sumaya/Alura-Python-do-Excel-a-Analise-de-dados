# %% [markdown]
# ## Aula 2
# Importação

# %%
import pandas as pd

# %%
df_principal = pd.read_excel("C:\\Users\\Usuario\\Desktop\\documentos\\projetos python\\Imersão Python\\Cópia de [Faça uma cópia para editar] Imersão Python - Tabela de ações (4).xlsx", sheet_name="Principal")
df_principal.head(10)
# Out:
#    Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0  USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1  CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2  PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3  SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4  CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# 5  PRIO3 2024-01-26        45.69          1.98           2.42         -0.78
# 6  PETR4 2024-01-26        39.96          1.73           6.47          7.30
# 7  VALE3 2024-01-26        69.50          1.66           2.06         -9.97
# 8  MULT3 2024-01-26        28.19          1.58           2.03         -0.81
# 9  ITUB4 2024-01-26        32.81          1.48          -0.39         -3.36
#
#    Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx    Volume  Variação %  \
# ...

# %% [markdown]
# Para rodar o código, é necessário instalar "openpyxl" junto do pandas

# %%
df_total_de_acoes = pd.read_excel("C:\\Users\\Usuario\\Desktop\\documentos\\projetos python\\Imersão Python\\Cópia de [Faça uma cópia para editar] Imersão Python - Tabela de ações (4).xlsx", sheet_name="Total_de_acoes")
df_total_de_acoes.head(10)
# Out:
#   Código  Qtde. Teórica
# 0  RRRP3   235665566.00
# 1  ALOS3   532616595.00
# 2  ALPA4   176733968.00
# 3  ABEV3  4394245879.00
# 4  ARZZ3    62305891.00
# 5  ASAI3  1349217892.00
# 6  AZUL4   327593725.00
# 7  B3SA3  5602790110.00
# 8  BBSE3   671750768.00
# 9  BBDC3  1500728902.00

# %% [markdown]
# O número é apresentado em notação científica

# %%
df_ticker = pd.read_excel("C:\\Users\\Usuario\\Desktop\\documentos\\projetos python\\Imersão Python\\Cópia de [Faça uma cópia para editar] Imersão Python - Tabela de ações (4).xlsx", sheet_name="Ticker")
df_ticker.head(10)
# Out:
#   Ticker            Nome
# 0  MGLU3  Magazine Luiza
# 1  HAPV3         Hapvida
# 2  PETR4       Petrobras
# 3  B3SA3              B3
# 4  USIM5        Usiminas
# 5  CVCB3             CVC
# 6  CIEL3           Cielo
# 7  VALE3            Vale
# 8  GOLL4             GOL
# 9  BBDC4  Banco Bradesco

# %%
df_chat_gpt = pd.read_excel("C:\\Users\\Usuario\\Desktop\\documentos\\projetos python\\Imersão Python\\Cópia de [Faça uma cópia para editar] Imersão Python - Tabela de ações (4).xlsx", sheet_name="GPT")
df_chat_gpt.head(10)
# Out:
#   Nome da Empresa          Segmento  Idade (aproximada)
# 0        Usiminas        Siderurgia                  60
# 1   CSN Mineração         Mineração                  20
# 2       Petrobras          Petróleo                  70
# 3          Suzano  Papel e Celulose                 100
# 4    CPFL Energia           Energia                 110
# 5        PetroRio          Petróleo                  15
# 6       Petrobras          Petróleo                  70
# 7            Vale         Mineração                  80
# 8       Multiplan          Shopping                  50
# 9   Itaú Unibanco             Banco                  20

# %%
df_principal = df_principal[['Ativo', 'Data', 'Último (R$)', 'Var. Dia (%)']].copy()
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)
# 0   USIM5 2024-01-26         9.50          5.20
# 1   CMIN3 2024-01-26         6.82          2.40
# 2   PETR3 2024-01-26        41.96          2.19
# 3   SUZB3 2024-01-26        52.91          2.04
# 4   CPFE3 2024-01-26        37.10          2.03
# ..    ...        ...          ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45
# 77  BHIA3 2024-01-26         8.70         -2.46
# 78  RENT3 2024-01-26        56.24         -3.63
# 79  CVCB3 2024-01-26         3.07         -4.36
# 80  GOLL4 2024-01-26         5.92         -8.07
#
# [81 rows x 4 columns]

# %%
df_principal = df_principal.rename(columns={"Último (R$)": "valor_final", "Var. Dia (%)": "var_dia_pct"}).copy()
#importância do .copy é para alterar os dados sem alterar a planília do excel
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct
# 0   USIM5 2024-01-26         9.50         5.20
# 1   CMIN3 2024-01-26         6.82         2.40
# 2   PETR3 2024-01-26        41.96         2.19
# 3   SUZB3 2024-01-26        52.91         2.04
# 4   CPFE3 2024-01-26        37.10         2.03
# ..    ...        ...          ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45
# 77  BHIA3 2024-01-26         8.70        -2.46
# 78  RENT3 2024-01-26        56.24        -3.63
# 79  CVCB3 2024-01-26         3.07        -4.36
# 80  GOLL4 2024-01-26         5.92        -8.07
#
# [81 rows x 4 columns]

# %% [markdown]
#  Criação da coluna Variação em porcentagem, valor inicial

# %%
df_principal['var_pct'] = df_principal["var_dia_pct"]/100
df_principal['valor_inicial']= df_principal["valor_final"]/(df_principal['var_pct']+1)
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  var_pct  valor_inicial
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
# [81 rows x 6 columns]

# %%
df_principal = df_principal.merge(df_total_de_acoes, left_on='Ativo', right_on="Código", how='left')
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  var_pct  valor_inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66  CMIN3
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06  PETR3
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85  SUZB3
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36  CPFE3
# ..    ...        ...          ...          ...      ...            ...    ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98  CRFB3
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92  BHIA3
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36  RENT3
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21  CVCB3
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44  GOLL4
#
#     Qtde. Teórica
# ...

# %%
df_principal = df_principal.drop(columns=["Código"])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica
# 0    515117391.00
# 1   1110559345.00
# 2   2379877655.00
# 3    683452836.00
# ...

# %%
df_principal['variacao_reais'] = (df_principal["valor_final"] - df_principal['valor_inicial'])*df_principal['Qtde. Teórica']
pd.options.display.float_format = '{:.2f}'.format
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica  variacao_reais
# 0    515117391.00    241889725.43
# 1   1110559345.00    177515970.30
# ...

# %%
df_principal['Qtde. Teórica'] =df_principal['Qtde. Teórica'].astype(int)
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica  variacao_reais
# 0       515117391    241889725.43
# 1      1110559345    177515970.30
# ...

# %%
df_principal = df_principal.rename(columns={"Qtde. Teórica": "qtde_teorica"}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtde_teorica  variacao_reais
# 0      515117391    241889725.43
# 1     1110559345    177515970.30
# ...

# %%
df_principal["resultado"]= df_principal["variacao_reais"].apply(lambda x: 'Subiu' if x > 0 else ('Desceu' if x < 0 else 'Estável'))
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtde_teorica  variacao_reais resultado
# 0      515117391    241889725.43     Subiu
# ...

# %%
df_principal = df_principal.merge(df_ticker, left_on='Ativo', right_on="Ticker", how='left')
df_principal = df_principal.drop(columns=["Ticker"])
df_principal = df_principal.rename(columns={"Nome": "nome"}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtde_teorica  variacao_reais resultado              nome
# ...

# %%
df_principal = df_principal.merge(df_chat_gpt, left_on='nome', right_on="Nome da Empresa", how='left')
df_principal = df_principal.drop(columns=["Nome da Empresa"])
df_principal = df_principal.rename(columns={"Idade (aproximada)": "idade_aproximada"}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 4   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# ..    ...        ...          ...          ...      ...            ...
# 80  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 81  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 82  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 83  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 84  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtde_teorica  variacao_reais resultado              nome  \
# ...

# %%
df_principal["cat_idade"] = df_principal["idade_aproximada"].apply(lambda x: 'Mais de 100' if x > 100 else ('Menos de 50' if x < 50 else "Entre 50 e 100"))
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 4   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# ..    ...        ...          ...          ...      ...            ...
# 80  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 81  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 82  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 83  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 84  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtde_teorica  variacao_reais resultado              nome  \
# ...

# %% [markdown]
# ## Aula 3
# Análises

# %% [markdown]
# Análise Geral

# %%
maior = df_principal['variacao_reais'].max()

menor = df_principal['variacao_reais'].min()

media = df_principal['variacao_reais'].mean()

media_subiu = df_principal[df_principal['resultado'] == 'Subiu']['variacao_reais'].mean()
media_desceu = df_principal[df_principal['resultado'] == 'Desceu']['variacao_reais'].mean()

print(f"Maior\tR$ {maior:,.2f}")
print(f"Menor\tR$ {menor:,.2f}")
print(f"Média\tR$ {media:,.2f}")
print(f"Média de quem subiu\tR$ {media_subiu:,.2f}")
print(f"Média de quem desceu\tR$ {media_desceu:,.2f}")
# Out:
# Maior	R$ 4,762,926,995.25
# Menor	R$ -1,807,432,634.46
# Média	R$ 229,644,360.94
# Média de quem subiu	R$ 538,720,638.36
# Média de quem desceu	R$ -181,109,141.75

# %% [markdown]
# Análise Segmento

# %%
df_principal_subiu = df_principal[df_principal['resultado'] == 'Subiu']
df_principal_subiu.head(10)
# Out:
#    Ativo       Data  valor_final  var_dia_pct  var_pct  valor_inicial  \
# 0  USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1  CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2  PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3  PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 4  SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 5  CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# 6  PRIO3 2024-01-26        45.69         1.98     0.02          44.80
# 7  PETR4 2024-01-26        39.96         1.73     0.02          39.28
# 8  PETR4 2024-01-26        39.96         1.73     0.02          39.28
# 9  VALE3 2024-01-26        69.50         1.66     0.02          68.37
#
#    qtde_teorica  variacao_reais resultado           nome          Segmento  \
# 0     515117391    241889725.43     Subiu       Usiminas        Siderurgia
# ...

# %%
df_analise_segmento = df_principal_subiu.groupby('Segmento')['variacao_reais'].sum().reset_index()
df_analise_segmento
# Out:
#             Segmento  variacao_reais
# 0          Alimentos    414174599.32
# 1              Banco   4636679965.25
# 2         Construção     37525872.38
# 3           Educação     72295838.99
# 4            Energia    839184846.22
# 5            Holding    373853994.88
# 6      Investimentos     42238249.54
# 7          Logística    233902674.79
# 8          Mineração   4940442965.55
# 9               Moda     41021792.09
# 10        Pagamentos     43657683.38
# 11  Papel e Celulose    722946282.71
# 12          Petróleo  11725189740.96
# 13           Química     69054317.64
# 14             Saúde    656270380.75
# 15          Shopping    117732680.08
# 16        Siderurgia    489935930.93
# 17        Tecnologia     15598886.65
# 18  Telecomunicações    292938114.42
# 19        Transporte     65452205.55
# 20            Varejo     28493619.27

# %% [markdown]
# Análise de saldo

# %%
df_analise_saldo = df_principal.groupby('resultado')['variacao_reais'].sum().reset_index()
df_analise_saldo
# Out:
#   resultado  variacao_reais
# 0    Desceu  -6338819961.32
# 1   Estável            0.00
# 2     Subiu  25858590641.35

# %% [markdown]
# ### Criação de Gráficos

# %%
import plotly.express as px

# %%
fig = px.bar(df_analise_saldo, x = "resultado", y = "variacao_reais", text="variacao_reais", title = "Variação reais por resultado")
fig.show()

# %% [markdown]
# ## Aula 4
# Gráficos de velas

# %%
 import matplotlib.pyplot as plt
 import matplotlib.dates as mdates
 import mplfinance as mpf
 import yfinance as yf
 import plotly.graph_objects as go 
 from plotly.subplots import make_subplots

# %%
dados = yf.download('PETR4.SA', start = '2023-01-01', end='2023-12-31')
dados
# Out:
# [*********************100%%**********************]  1 of 1 completed
#             Open  High   Low  Close  Adj Close     Volume
# Date
# 2023-01-02 23.54 23.81 22.80  22.92      17.71   78424700
# 2023-01-03 22.94 23.10 22.13  22.34      17.26   96750300
# 2023-01-04 21.96 23.59 21.83  23.05      17.81  129504000
# 2023-01-05 23.34 24.04 23.15  23.88      18.45   73886000
# 2023-01-06 23.94 24.32 23.55  23.74      18.34   51851500
# ...          ...   ...   ...    ...        ...        ...
# 2023-12-21 36.67 36.68 36.07  36.39      36.39   30511900
# 2023-12-22 36.50 36.80 36.37  36.74      36.74   31234700
# 2023-12-26 36.86 37.37 36.83  37.33      37.33   23466800
# 2023-12-27 37.32 37.43 37.13  37.36      37.36   19588500
# 2023-12-28 37.23 37.36 37.04  37.24      37.24   21421900
#
# [248 rows x 6 columns]

# %%
dados.columns = [ 'abertura', 'maximo', 'minimo', 'fechamento', 'fech_ajust', 'volume' ]
dados
# Out:
#             abertura  maximo  minimo  fechamento  fech_ajust     volume
# Date
# 2023-01-02     23.54   23.81   22.80       22.92       17.71   78424700
# 2023-01-03     22.94   23.10   22.13       22.34       17.26   96750300
# 2023-01-04     21.96   23.59   21.83       23.05       17.81  129504000
# 2023-01-05     23.34   24.04   23.15       23.88       18.45   73886000
# 2023-01-06     23.94   24.32   23.55       23.74       18.34   51851500
# ...              ...     ...     ...         ...         ...        ...
# 2023-12-21     36.67   36.68   36.07       36.39       36.39   30511900
# 2023-12-22     36.50   36.80   36.37       36.74       36.74   31234700
# 2023-12-26     36.86   37.37   36.83       37.33       37.33   23466800
# 2023-12-27     37.32   37.43   37.13       37.36       37.36   19588500
# 2023-12-28     37.23   37.36   37.04       37.24       37.24   21421900
#
# [248 rows x 6 columns]

# %%
dados = dados.rename_axis('Data')
dados
# Out:
#             abertura  maximo  minimo  fechamento  fech_ajust     volume
# Data
# 2023-01-02     23.54   23.81   22.80       22.92       17.71   78424700
# 2023-01-03     22.94   23.10   22.13       22.34       17.26   96750300
# 2023-01-04     21.96   23.59   21.83       23.05       17.81  129504000
# 2023-01-05     23.34   24.04   23.15       23.88       18.45   73886000
# 2023-01-06     23.94   24.32   23.55       23.74       18.34   51851500
# ...              ...     ...     ...         ...         ...        ...
# 2023-12-21     36.67   36.68   36.07       36.39       36.39   30511900
# 2023-12-22     36.50   36.80   36.37       36.74       36.74   31234700
# 2023-12-26     36.86   37.37   36.83       37.33       37.33   23466800
# 2023-12-27     37.32   37.43   37.13       37.36       37.36   19588500
# 2023-12-28     37.23   37.36   37.04       37.24       37.24   21421900
#
# [248 rows x 6 columns]

# %%
dados['fechamento'].plot(figsize=(10,6))
plt.title('Variação do preço por data', fontsize=10)
plt.legend(['Fechamento'])

# %%
df = dados.head(60).copy()
#Converte o índice em uma coluna de data 
df['Data'] = df.index
#Convertendo as datas para o formato numérico de matplotlib
#Isso é necessário para que o Matplotlib possa plotar as datas corretamente no gráfico
df['Data'] = df['Data'].apply(mdates.date2num)
df
# Out:
#             abertura  maximo  minimo  fechamento  fech_ajust     volume  \
# Data
# 2023-01-02     23.54   23.81   22.80       22.92       17.71   78424700
# 2023-01-03     22.94   23.10   22.13       22.34       17.26   96750300
# 2023-01-04     21.96   23.59   21.83       23.05       17.81  129504000
# 2023-01-05     23.34   24.04   23.15       23.88       18.45   73886000
# 2023-01-06     23.94   24.32   23.55       23.74       18.34   51851500
# 2023-01-09     23.50   24.00   23.25       23.87       18.44   46385200
# 2023-01-10     23.95   24.11   23.37       24.09       18.61   52741100
# 2023-01-11     24.15   24.62   24.05       24.28       18.76   53536500
# 2023-01-12     24.29   24.65   24.11       24.63       19.03   58130000
# 2023-01-13     24.44   24.66   24.25       24.57       18.98   40002700
# 2023-01-16     24.41   24.50   23.83       24.04       18.57   31973700
# 2023-01-17     24.11   25.62   24.11       25.52       19.72   91797500
# ...

# %%
fig, ax = plt.subplots(figsize=(15, 8))

width = 0.7

for i in range(len(df)):
    #determine a cor do candle
    #se o preço de fechamento é maior que o de abertura o candle é verde (valorização da ação)
    #se for menor, o candle é vermelho (desvalorização)
    if df['fechamento'].iloc[i] > df['abertura'].iloc[i]:
        color = 'green'
    else:
        color = 'red'
        
    #desenhando a linha vertical do candle (mecha)
    #essa linha mostra os preços máximo e(topo da linha) e mínimo (nase da linha) do dia
    #usamos 'ax.plot' para desenhar uma linhas vertical 
    # [df['Data'].iloc[i], df['Data'].iloc[i]] define o ponto x da linha (a data), e [df['Mínimo'].iloc[i], df['Máximo'].iloc[i] define a ]
    ax.plot([df['Data'].iloc[i], df['Data'].iloc[i]],
            [df['minimo'].iloc[i], df['maximo'].iloc[i]],
            color=color,
            linewidth=1)
    
    ax.add_patch(plt.Rectangle((df['Data'].iloc[i] - width/2, min(df['abertura'].iloc[i], df['fechamento'].iloc[i])),
                                width,
                                abs(df['fechamento'].iloc[i] - df['abertura'].iloc[i]),
                                facecolor=color))
    
df["MA7"] = df['fechamento'].rolling(window=7).mean()
df["MA14"] = df['fechamento'].rolling(window=14).mean()

#Plotando as médias móves
ax.plot(df['Data'], df['MA7'], color='orange', label = 'Média Móvel 7 Dias')
ax.plot(df['Data'], df['MA14'], color='purple', label = 'Média Móvel 14 Dias')
#adicionando legendas para as médias móveis 
ax.legend()

#formatação do eixo x para mostrar as datas 
# configuração o formato da data e a rotação para melhor legibilidade 
ax.xaxis_date() #o método xaxis_date() é usado para dizer ao Matplotlib que as datas estão sendo usadas no eixo x
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.xticks(rotation=45)

# adicionando titilo e rótulos para os eixos x e y
plt.title("Gráfico de Canlestick - PETR4.SA com matplotlib")
plt.xlabel('Data')
plt.ylabel('Preço')

# adicionando ima grade para facilitar a visualização dos valores 
plt.grid(True)

#exibindo os gráficos
plt.show()

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# Criação do gráfico
fig = make_subplots(rows=2, cols=1, shared_xaxes=True,
                    vertical_spacing=0.1,
                    subplot_titles=('Candlesticks', 'Volume Transacionado'),
                    row_width=[0.2, 0.7])

# Adicionando o gráfico de candlestick
fig.add_trace(go.Candlestick(x=df.index,
                             open=df['abertura'],
                             high=df['maximo'],
                             low=df['minimo'],
                             close=df['fechamento'],
                             name='Candlestick'),
              row=1, col=1)

# Adicionando o gráfico de barras ao volume com a cor roxa
fig.add_trace(go.Bar(x=df.index,
                     y=df['volume'],
                     name='Volume',
                     marker_color='purple'),  # Definindo a cor roxa
              row=2, col=1)

# Atualização do layout
fig.update_layout(yaxis_title='Preço',
                  xaxis_rangeslider_visible=False,
                  width=1100, height=600)

# Exibição do gráfico
fig.show()

# %%
dados = yf.download('PETR4.SA', start = '2023-01-01', end='2023-12-31')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
mpf.plot(dados.head(30), type="candle", figsize =(16,8), volume=True, mav=(7,14), style='yahoo')

# %% [markdown]
# ## Aula 5

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from prophet import Prophet
     

dados = yf.download("JNJ", start="2020-01-01", end="2023-12-31", progress=False)
dados = dados.reset_index()
dados
     

dados_treino = dados[dados['Date'] < '2023-07-31']
dados_teste = dados[dados['Date'] >= '2023-07-31']
     

dados_prophet_treino = dados_treino[['Date', 'Close']].rename(columns={'Date': 'ds', 'Close': 'y'})
dados_prophet_treino

     

modelo = Prophet(weekly_seasonality=True,
        yearly_seasonality=True,
        daily_seasonality=False)

modelo.add_country_holidays(country_name='US')

modelo.fit(dados_prophet_treino)
     

futuro = modelo.make_future_dataframe(periods=150)
previsao = modelo.predict(futuro)
previsao
     

#Previsão
plt.figure(figsize=(10, 7))
plt.plot(dados_treino['Date'], dados_treino['Close'], label='Dados de Treino', color='blue')
plt.plot(dados_teste['Date'], dados_teste['Close'], label='Dados Reais (Teste)', color='green')
plt.plot(previsao['ds'], previsao['yhat'], label='Previsão', color='orange', linestyle='--')

plt.axvline(dados_treino['Date'].max(), color='red', linestyle='--', label='Início da Previsão')
plt.xlabel('Data')
plt.ylabel('Preço de Fechamento')
plt.title('Previsão de Preço de Fechamento vs Dados Reais')
plt.legend()
plt.show()
# Out:
# 15:53:06 - cmdstanpy - INFO - Chain [1] start processing
# 15:53:07 - cmdstanpy - INFO - Chain [1] done processing
